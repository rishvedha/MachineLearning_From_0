# %%
# !pip install PyPDF2 pandas

# %%
import PyPDF2
import pandas as pd
def pdf_to_csv(pdf_file,csv_file):
    try:
        with open(pdf_file,'rb')as pdf:
            reader=PyPDF2.PdfReader(pdf)
            text_data=[]
            
            for page in reader.pages:
                text_data.append(page.extract_text())
                rows=[line.split()for page in text_data for line in page.split('\n')]
                df=pd.DataFrame(rows)
                df.to_csv(csv_file,index=False,header=False)
                print(f"PDF file'{pdf_file}' has been successfully converted to CSV '{csv_file}'")
    except Exception as e :
                    print(f"error:{e}")

# %%
pdf_file="Downloads/msctimetable.pdf"
csv_file="msc.csv"
pdf_to_csv(pdf_file,csv_file)
# Out:
# PDF file'Downloads/msctimetable.pdf' has been successfully converted to CSV 'msc.csv'
# PDF file'Downloads/msctimetable.pdf' has been successfully converted to CSV 'msc.csv'
# PDF file'Downloads/msctimetable.pdf' has been successfully converted to CSV 'msc.csv'

# %%
import PyPDF2
import pandas as pd
def pdf_to_csv(pdf_file,csv_file):
    try:
        with open(pdf_file,'rb')as pdf:
            reader=PyPDF2.PdfReader(pdf)
            text_data=[]
            
            for page in reader.pages:
                text_data.append(page.extract_text())
                rows=[line.split()for page in text_data for line in page.split('\n')]
                df=pd.DataFrame(rows)
                df.to_csv(csv_file,index=False,header=False)
                print(f"PDF file'{pdf_file}' has been successfully converted to CSV '{csv_file}'")
    except Exception as e :
                    print(f"error:{e}")

# %%
pdf_file="Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf"
csv_file="anithamammaterial.csv"
pdf_to_csv(pdf_file,csv_file)
# Out:
# PDF file'Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf' has been successfully converted to CSV 'anithamammaterial.csv'
# PDF file'Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf' has been successfully converted to CSV 'anithamammaterial.csv'
# PDF file'Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf' has been successfully converted to CSV 'anithamammaterial.csv'
# PDF file'Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf' has been successfully converted to CSV 'anithamammaterial.csv'
# PDF file'Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf' has been successfully converted to CSV 'anithamammaterial.csv'
# PDF file'Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf' has been successfully converted to CSV 'anithamammaterial.csv'
# PDF file'Downloads/Ver3_Full Manual_Predictive analytics Lab.pdf' has been successfully converted to CSV 'anithamammaterial.csv'
# ...

# %%
df=pd.read_csv("anithamammaterial.csv")

# %%
df.head()
# Out:
#      Predictive       Analytics         Lab       – 23DS470 Unnamed: 5  \
# 0           NaN             NaN         NaN     NaN     NaN        NaN
# 1  Dr.D.Anitha,  Dr.C.Mahadevi,  Mrs.Anitha  Gracy,   Dept.         of
# 2           NaN             NaN         NaN     NaN     NaN        NaN
# 3           NaN             NaN         NaN     NaN     NaN        NaN
# 4           NaN             NaN         NaN     NaN     NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1       AMCS       Page          1        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0         NaN         NaN         NaN         NaN
# ...

# %%
dc=pd.read_csv("msc.csv")
dc.head()
# Out:
#    THIAGARAJAR  COLLEGE           OF ENGINEERING,        MADURAI           –  \
# 0           (A     Govt        Aided   Autonomous    Institution  Affiliated
# 1          NaN      NaN          NaN          NaN            NaN         NaN
# 2          LAB     TIME        TABLE         EVEN       SEMESTER        2024
# 3  Department:  Applied  Mathematics            &  Computational     Science
# 4          NaN      NaN          NaN          NaN            NaN         NaN
#
#      625    015   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0     to   Anna  University)        NaN         NaN         NaN         NaN
# 1    NaN    NaN          NaN        NaN         NaN         NaN         NaN
# 2  -2025    NaN          NaN        NaN         NaN         NaN         NaN
# 3    Lab  Name:          IBM      (Data    Science)         Lab         NaN
# 4    NaN    NaN          NaN        NaN         NaN         NaN         NaN
#
# ...

# %%
class
def header(self):
self.set_font('Arial', 'B', 12)
self.cell(0, 10, 'CSV to PDF Conversion', 0, 1, 'C')
def footer(self):
self.set_y(-15)
self.set_font('Arial', 'I', 8)
self.cell(0, 10, f'Page {self.page_no()}', 0, 0, 'C')
def csv_to_pdf(csv_file, pdf_file):
try:
df = pd.read_csv(csv_file)
pdf = PDF()
pdf.add_page()
pdf.set_font('Arial', '', 10)
col_widths = [40] * len(df.columns)
pdf.set_fill_color(200, 220, 255)
for col in df.columns:
pdf.cell(col_widths[df.columns.get_loc(col)], 10, str(col), 1, 0, 'C',
fill=True)
pdf.ln()

     for _, row in df.iterrows():
        for col in df.columns:
            df.cell(col_widths[df.columns.get_loc(col)], 10, str(row[col]), 1,0, 'C')
pdf.ln()
pdf.output(pdf_file)
print(f"CSV file '{csv_file}' has been successfully converted to PDF file'{pdf_file}'.")
   except Exception as e:
        print(f"Error: {e}")

# %%
csv_file = "input.csv"
pdf_file = "output.pdf" 
csv_to_pdf(csv_file, pdf_file)
